# %%
import pandas as pd
import matplotlib.pyplot as plt

from IPython.display import set_matplotlib_formats
from matplotlib_inline.backend_inline import set_matplotlib_formats as set_matplotlib_formats_new

# %%
deform =    pd.read_csv('randbig_deformcnn_ee_kine/progress.csv')
dual =      pd.read_csv('randbig_dualcnn_ee_kine/progress.csv')
nature =    pd.read_csv('randbig_naturecnn_ee_kine/progress.csv')

fig, axs = plt.subplots(1,2, figsize = (16,6))

axs[0].plot(deform['time/total_timesteps']/1000, deform['rollout/success_rate'], label = 'SAC DeformableCNN')
axs[0].set_xlabel('Timesteps ($10^3$)')
axs[0].set_ylabel('Success Rate')
axs[0].legend(fontsize="8")

axs[0].plot(dual['time/total_timesteps']/1000, dual['rollout/success_rate'], label = 'SAC DualCNN')
axs[0].set_xlabel('Timesteps ($10^3$)')
axs[0].set_ylabel('Success Rate')
axs[0].legend(fontsize="8")

axs[0].plot(nature['time/total_timesteps']/1000, nature['rollout/success_rate'], label = 'SAC NatureCNN')
axs[0].set_xlabel('Timesteps ($10^3$)')
axs[0].set_ylabel('Success Rate')
axs[0].legend(fontsize="8")

#######################################################################################################

axs[1].plot(deform['time/total_timesteps']/1000, deform['rollout/ep_rew_mean'], label = 'SAC DeformableCNN')
axs[1].set_xlabel('Timesteps ($10^3$)')
axs[1].set_ylabel('Mean Episode Reward')
axs[1].legend(fontsize="8")

axs[1].plot(dual['time/total_timesteps']/1000, dual['rollout/ep_rew_mean'], label = 'SAC DualCNN')
axs[1].set_xlabel('Timesteps ($10^3$)')
axs[1].set_ylabel('Mean Episode Reward')
axs[1].legend(fontsize="8")

axs[1].plot(nature['time/total_timesteps']/1000, nature['rollout/ep_rew_mean'], label = 'SAC NatureCNN')
axs[1].set_xlabel('Timesteps ($10^3$)')
axs[1].set_ylabel('Mean Episode Reward')
axs[1].legend(fontsize="8")

fig.suptitle('Training Result for Different CNN encoders')
plt.savefig('sac_cnn_compare.png', format='png')

# %%
deform =    pd.read_csv('randbig_deformcnn_ee_kine/progress.csv')
lstm =      pd.read_csv('randbig_lstm_ee_kine/progress.csv')
lstm_nk =   pd.read_csv('randbig_lstm_ee/progress.csv')

fig, axs = plt.subplots(1,2, figsize = (16,6))

axs[0].plot(deform['time/total_timesteps']/1000, deform['rollout/success_rate'], label = 'SAC DeformableCNN')
axs[0].set_xlabel('Timesteps ($10^3$)')
axs[0].set_ylabel('Success Rate')
axs[0].legend(fontsize="8")

axs[0].plot(lstm['time/total_timesteps']/1000, lstm['rollout/success_rate'], label = 'SAC NatureCNN_LSTM')
axs[0].set_xlabel('Timesteps ($10^3$)')
axs[0].set_ylabel('Success Rate')
axs[0].legend(fontsize="8")

axs[0].plot(lstm_nk['time/total_timesteps']/1000, lstm_nk['rollout/success_rate'], label = 'SAC NatureCNN_LSTM_nokine')
axs[0].set_xlabel('Timesteps ($10^3$)')
axs[0].set_ylabel('Success Rate')
axs[0].legend(fontsize="8")

#######################################################################################################

axs[1].plot(deform['time/total_timesteps']/1000, deform['rollout/ep_rew_mean'], label = 'SAC DeformableCNN')
axs[1].set_xlabel('Timesteps ($10^3$)')
axs[1].set_ylabel('Mean Episode Reward')
axs[1].legend(fontsize="8")

axs[1].plot(lstm['time/total_timesteps']/1000, lstm['rollout/ep_rew_mean'], label = 'SAC NatureCNN_LSTM')
axs[1].set_xlabel('Timesteps ($10^3$)')
axs[1].set_ylabel('Mean Episode Reward')
axs[1].legend(fontsize="8")

axs[1].plot(lstm_nk['time/total_timesteps']/1000, lstm_nk['rollout/ep_rew_mean'], label = 'SAC NatureCNN_LSTM_nokine')
axs[1].set_xlabel('Timesteps ($10^3$)')
axs[1].set_ylabel('Mean Episode Reward')
axs[1].legend(fontsize="8")

fig.suptitle('Training Result for LSTM encoders w/wo Robot Kinematics Information')
plt.savefig('sac_lstm_compare.png', format='png')

# %%
deform_k =    pd.read_csv('sine/sine_deformcnn_ee_kine/progress.csv')
dual_k =      pd.read_csv('sine/sine_dualcnn_ee_kine/progress.csv')
nature_k =    pd.read_csv('sine/sine_naturecnn_ee_kine/progress.csv')

deform =    pd.read_csv('sine/sine_deformcnn_ee/progress.csv')
dual =      pd.read_csv('sine/sine_dualcnn_ee/progress.csv')
nature =    pd.read_csv('sine/sine_naturecnn_ee/progress.csv')

fig, axs = plt.subplots(2,2, figsize = (16,8))

axs[0][0].plot(deform['time/total_timesteps']/1000, deform['rollout/success_rate'], label = 'SAC DeformableCNN')
axs[0][0].set_xlabel('Timesteps ($10^3$)')
axs[0][0].set_ylabel('Success Rate')
axs[0][0].legend(fontsize="8")

axs[0][0].plot(dual['time/total_timesteps']/1000, dual['rollout/success_rate'], label = 'SAC DualCNN')
axs[0][0].set_xlabel('Timesteps ($10^3$)')
axs[0][0].set_ylabel('Success Rate')
axs[0][0].legend(fontsize="8")

axs[0][0].plot(nature['time/total_timesteps']/1000, nature['rollout/success_rate'], label = 'SAC NatureCNN')
axs[0][0].set_xlabel('Timesteps ($10^3$)')
axs[0][0].set_ylabel('Success Rate')
axs[0][0].legend(fontsize="8")

#######################################################################################################

axs[0][1].plot(deform['time/total_timesteps']/1000, deform['rollout/ep_rew_mean'], label = 'SAC DeformableCNN')
axs[0][1].set_xlabel('Timesteps ($10^3$)')
axs[0][1].set_ylabel('Mean Episode Reward')
axs[0][1].legend(fontsize="8")

axs[0][1].plot(dual['time/total_timesteps']/1000, dual['rollout/ep_rew_mean'], label = 'SAC DualCNN')
axs[0][1].set_xlabel('Timesteps ($10^3$)')
axs[0][1].set_ylabel('Mean Episode Reward')
axs[0][1].legend(fontsize="8")

axs[0][1].plot(nature['time/total_timesteps']/1000, nature['rollout/ep_rew_mean'], label = 'SAC NatureCNN')
axs[0][1].set_xlabel('Timesteps ($10^3$)')
axs[0][1].set_ylabel('Mean Episode Reward')
axs[0][1].legend(fontsize="8")

#######################################################################################################

axs[1][0].plot(deform_k['time/total_timesteps']/1000, deform_k['rollout/success_rate'], label = 'SAC DeformableCNN Kine')
axs[1][0].set_xlabel('Timesteps ($10^3$)')
axs[1][0].set_ylabel('Success Rate')
axs[1][0].legend(fontsize="8")

axs[1][0].plot(dual_k['time/total_timesteps']/1000, dual_k['rollout/success_rate'], label = 'SAC DualCNN Kine')
axs[1][0].set_xlabel('Timesteps ($10^3$)')
axs[1][0].set_ylabel('Success Rate')
axs[1][0].legend(fontsize="8")

axs[1][0].plot(nature_k['time/total_timesteps']/1000, nature_k['rollout/success_rate'], label = 'SAC NatureCNN Kine')
axs[1][0].set_xlabel('Timesteps ($10^3$)')
axs[1][0].set_ylabel('Success Rate')
axs[1][0].legend(fontsize="8")

#######################################################################################################

axs[1][1].plot(deform_k['time/total_timesteps']/1000, deform_k['rollout/ep_rew_mean'], label = 'SAC DeformableCNN Kine')
axs[1][1].set_xlabel('Timesteps ($10^3$)')
axs[1][1].set_ylabel('Mean Episode Reward')
axs[1][1].legend(fontsize="8")

axs[1][1].plot(dual_k['time/total_timesteps']/1000, dual_k['rollout/ep_rew_mean'], label = 'SAC DualCNN Kine')
axs[1][1].set_xlabel('Timesteps ($10^3$)')
axs[1][1].set_ylabel('Mean Episode Reward')
axs[1][1].legend(fontsize="8")

axs[1][1].plot(nature_k['time/total_timesteps']/1000, nature_k['rollout/ep_rew_mean'], label = 'SAC NatureCNN Kine')
axs[1][1].set_xlabel('Timesteps ($10^3$)')
axs[1][1].set_ylabel('Mean Episode Reward')
axs[1][1].legend(fontsize="8")

fig.suptitle('Training Result for CNN encoders w/wo Robot Kinematics Information')
plt.savefig('sac_kine_compare_sine.png', format='png')

# %%
deform_k =    pd.read_csv('randbig_deformcnn_ee_kine/progress.csv')
dual_k =      pd.read_csv('randbig_dualcnn_ee_kine/progress.csv')
nature_k =    pd.read_csv('randbig_naturecnn_ee_kine/progress.csv')

deform =    pd.read_csv('randbig_deformcnn_ee/progress.csv')
dual =      pd.read_csv('randbig_dualcnn_ee/progress.csv')
nature =    pd.read_csv('randbig_naturecnn_ee/progress.csv')

fig, axs = plt.subplots(2,2, figsize = (16,8))

axs[0][0].plot(deform['time/total_timesteps']/1000, deform['rollout/success_rate'], label = 'SAC DeformableCNN')
axs[0][0].set_xlabel('Timesteps ($10^3$)')
axs[0][0].set_ylabel('Success Rate')
axs[0][0].set_ylim(-0.05, 1.05)
axs[0][0].legend(fontsize="8")

axs[0][0].plot(dual['time/total_timesteps']/1000, dual['rollout/success_rate'], label = 'SAC DualCNN')
axs[0][0].set_xlabel('Timesteps ($10^3$)')
axs[0][0].set_ylabel('Success Rate')
axs[0][0].set_ylim(-0.05, 1.05)
axs[0][0].legend(fontsize="8")

axs[0][0].plot(nature['time/total_timesteps']/1000, nature['rollout/success_rate'], label = 'SAC NatureCNN')
axs[0][0].set_xlabel('Timesteps ($10^3$)')
axs[0][0].set_ylabel('Success Rate')
axs[0][0].set_ylim(-0.05, 1.05)
axs[0][0].legend(fontsize="8")

#######################################################################################################

axs[0][1].plot(deform['time/total_timesteps']/1000, deform['rollout/ep_rew_mean'], label = 'SAC DeformableCNN')
axs[0][1].set_xlabel('Timesteps ($10^3$)')
axs[0][1].set_ylabel('Mean Episode Reward')
axs[0][1].legend(fontsize="8")

axs[0][1].plot(dual['time/total_timesteps']/1000, dual['rollout/ep_rew_mean'], label = 'SAC DualCNN')
axs[0][1].set_xlabel('Timesteps ($10^3$)')
axs[0][1].set_ylabel('Mean Episode Reward')
axs[0][1].legend(fontsize="8")

axs[0][1].plot(nature['time/total_timesteps']/1000, nature['rollout/ep_rew_mean'], label = 'SAC NatureCNN')
axs[0][1].set_xlabel('Timesteps ($10^3$)')
axs[0][1].set_ylabel('Mean Episode Reward')
axs[0][1].legend(fontsize="8")

#######################################################################################################

axs[1][0].plot(deform_k['time/total_timesteps']/1000, deform_k['rollout/success_rate'], label = 'SAC DeformableCNN Kine')
axs[1][0].set_xlabel('Timesteps ($10^3$)')
axs[1][0].set_ylabel('Success Rate')
axs[1][0].legend(fontsize="8")

axs[1][0].plot(dual_k['time/total_timesteps']/1000, dual_k['rollout/success_rate'], label = 'SAC DualCNN Kine')
axs[1][0].set_xlabel('Timesteps ($10^3$)')
axs[1][0].set_ylabel('Success Rate')
axs[1][0].legend(fontsize="8")

axs[1][0].plot(nature_k['time/total_timesteps']/1000, nature_k['rollout/success_rate'], label = 'SAC NatureCNN Kine')
axs[1][0].set_xlabel('Timesteps ($10^3$)')
axs[1][0].set_ylabel('Success Rate')
axs[1][0].legend(fontsize="8")

#######################################################################################################

axs[1][1].plot(deform_k['time/total_timesteps']/1000, deform_k['rollout/ep_rew_mean'], label = 'SAC DeformableCNN Kine')
axs[1][1].set_xlabel('Timesteps ($10^3$)')
axs[1][1].set_ylabel('Mean Episode Reward')
axs[1][1].legend(fontsize="8")

axs[1][1].plot(dual_k['time/total_timesteps']/1000, dual_k['rollout/ep_rew_mean'], label = 'SAC DualCNN Kine')
axs[1][1].set_xlabel('Timesteps ($10^3$)')
axs[1][1].set_ylabel('Mean Episode Reward')
axs[1][1].legend(fontsize="8")

axs[1][1].plot(nature_k['time/total_timesteps']/1000, nature_k['rollout/ep_rew_mean'], label = 'SAC NatureCNN Kine')
axs[1][1].set_xlabel('Timesteps ($10^3$)')
axs[1][1].set_ylabel('Mean Episode Reward')
axs[1][1].legend(fontsize="8")

fig.suptitle('Training Result for CNN encoders w/wo Robot Kinematics Information')
plt.savefig('sac_kine_compare_randbig.png', format='png')
