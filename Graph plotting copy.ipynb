# %%
import pandas as pd
import matplotlib.pyplot as plt

from IPython.display import set_matplotlib_formats
from matplotlib_inline.backend_inline import set_matplotlib_formats as set_matplotlib_formats_new

# %%
deform =    pd.read_csv('randbig_deformcnn_ee/progress.csv')
dual =      pd.read_csv('randbig_dualcnn_ee/progress.csv')
nature =    pd.read_csv('randbig_naturecnn_ee/progress.csv')
lstm =      pd.read_csv('randbig_lstm_ee/progress.csv')

deform_k =    pd.read_csv('randbig_deformcnn_ee_kine/progress.csv')
dual_k =      pd.read_csv('randbig_dualcnn_ee_kine/progress.csv')
nature_k =    pd.read_csv('randbig_naturecnn_ee_kine/progress.csv')
lstm_k =      pd.read_csv('randbig_lstm_ee_kine/progress.csv')

fig, axs = plt.subplots(2,2, figsize = (16,8))

axs[0][0].plot(nature['time/total_timesteps']/1000, nature['rollout/success_rate'], label = 'NatureCNN')
axs[0][0].set_xlabel('Timesteps ($10^3$)', fontsize="14")
axs[0][0].set_ylabel('Success Rate', fontsize="14")
axs[0][0].set_ylim(-0.05, 1.05)
axs[0][0].legend(fontsize="12")

axs[0][0].plot(dual['time/total_timesteps']/1000, dual['rollout/success_rate'], label = 'DualCNN')
axs[0][0].set_xlabel('Timesteps ($10^3$)', fontsize="14")
axs[0][0].set_ylabel('Success Rate', fontsize="14")
axs[0][0].set_ylim(-0.05, 1.05)
axs[0][0].legend(fontsize="12")

axs[0][0].plot(deform['time/total_timesteps']/1000, deform['rollout/success_rate'], label = 'DeformableCNN')
axs[0][0].set_xlabel('Timesteps ($10^3$)', fontsize="14")
axs[0][0].set_ylabel('Success Rate', fontsize="14")
axs[0][0].set_ylim(-0.05, 1.05)
axs[0][0].legend(fontsize="12")

axs[0][0].plot(lstm['time/total_timesteps']/1000, lstm['rollout/success_rate'], label = 'NatureCNN LSTM')
axs[0][0].set_xlabel('Timesteps ($10^3$)', fontsize="14")
axs[0][0].set_ylabel('Success Rate', fontsize="14")
axs[0][0].set_ylim(-0.05, 1.05)
axs[0][0].legend(fontsize="12")

axs[0][0].set_title("Success Rate of 4 Extractors " + r"$\bf{without}$" + " Kinematic Information", fontsize="14")

#######################################################################################################

axs[0][1].plot(nature['time/total_timesteps']/1000, nature['rollout/ep_rew_mean'], label = 'NatureCNN')
axs[0][1].set_xlabel('Timesteps ($10^3$)', fontsize="14")
axs[0][1].set_ylabel('Mean Episode Reward', fontsize="14")
axs[0][1].legend(fontsize="12")

axs[0][1].plot(dual['time/total_timesteps']/1000, dual['rollout/ep_rew_mean'], label = 'DualCNN')
axs[0][1].set_xlabel('Timesteps ($10^3$)', fontsize="14")
axs[0][1].set_ylabel('Mean Episode Reward', fontsize="14")
axs[0][1].legend(fontsize="12")

axs[0][1].plot(deform['time/total_timesteps']/1000, deform['rollout/ep_rew_mean'], label = 'DeformableCNN')
axs[0][1].set_xlabel('Timesteps ($10^3$)', fontsize="14")
axs[0][1].set_ylabel('Mean Episode Reward', fontsize="14")
axs[0][1].legend(fontsize="12")

axs[0][1].plot(lstm['time/total_timesteps']/1000, lstm['rollout/ep_rew_mean'], label = 'NatureCNN LSTM')
axs[0][1].set_xlabel('Timesteps ($10^3$)', fontsize="14")
axs[0][1].set_ylabel('Mean Episode Reward', fontsize="14")
axs[0][1].legend(fontsize="12")

axs[0][1].set_title("Mean Episode Reward of 4 Extractors " + r"$\bf{without}$" + " Kinematic Information", fontsize="14")

#######################################################################################################

axs[1][0].plot(nature_k['time/total_timesteps']/1000, nature_k['rollout/success_rate'], label = 'NatureCNN Kine')
axs[1][0].set_xlabel('Timesteps ($10^3$)', fontsize="14")
axs[1][0].set_ylabel('Success Rate', fontsize="14")
axs[1][0].legend(fontsize="12")

axs[1][0].plot(dual_k['time/total_timesteps']/1000, dual_k['rollout/success_rate'], label = 'DualCNN Kine')
axs[1][0].set_xlabel('Timesteps ($10^3$)', fontsize="14")
axs[1][0].set_ylabel('Success Rate', fontsize="14")
axs[1][0].legend(fontsize="12")

axs[1][0].plot(deform_k['time/total_timesteps']/1000, deform_k['rollout/success_rate'], label = 'DeformableCNN Kine')
axs[1][0].set_xlabel('Timesteps ($10^3$)', fontsize="14")
axs[1][0].set_ylabel('Success Rate', fontsize="14")
axs[1][0].legend(fontsize="12")

axs[1][0].plot(lstm_k['time/total_timesteps']/1000, lstm_k['rollout/success_rate'], label = 'NatureCNN LSTM Kine')
axs[1][0].set_xlabel('Timesteps ($10^3$)', fontsize="14")
axs[1][0].set_ylabel('Success Rate', fontsize="14")
axs[1][0].legend(fontsize="12")

axs[1][0].set_title("Success Rate of 4 Extractors " + r"$\bf{with}$" + " Kinematic Information", fontsize="14")

#######################################################################################################

axs[1][1].plot(nature_k['time/total_timesteps']/1000, nature_k['rollout/ep_rew_mean'], label = 'NatureCNN Kine')
axs[1][1].set_xlabel('Timesteps ($10^3$)', fontsize="14")
axs[1][1].set_ylabel('Mean Episode Reward', fontsize="14")
axs[1][1].legend(fontsize="12")

axs[1][1].plot(dual_k['time/total_timesteps']/1000, dual_k['rollout/ep_rew_mean'], label = 'DualCNN Kine')
axs[1][1].set_xlabel('Timesteps ($10^3$)', fontsize="14")
axs[1][1].set_ylabel('Mean Episode Reward', fontsize="14")
axs[1][1].legend(fontsize="12")

axs[1][1].plot(deform_k['time/total_timesteps']/1000, deform_k['rollout/ep_rew_mean'], label = 'DeformableCNN Kine')
axs[1][1].set_xlabel('Timesteps ($10^3$)', fontsize="14")
axs[1][1].set_ylabel('Mean Episode Reward', fontsize="14")
axs[1][1].legend(fontsize="12")

axs[1][1].plot(lstm_k['time/total_timesteps']/1000, lstm_k['rollout/ep_rew_mean'], label = 'NatureCNN LSTM Kine')
axs[1][1].set_xlabel('Timesteps ($10^3$)', fontsize="14")
axs[1][1].set_ylabel('Mean Episode Reward', fontsize="14")
axs[1][1].legend(fontsize="12")

axs[1][1].set_title("Mean Episode Reward of 4 Extractors " + r"$\bf{with}$" + " Kinematic Information", fontsize="14")

axs[0][0].text(-0.08, 1, f'({chr(97 + 0)})', transform=axs[0][0].transAxes, verticalalignment='top', fontsize=12)
axs[0][1].text(-0.08, 1, f'({chr(97 + 1)})', transform=axs[0][1].transAxes, verticalalignment='top', fontsize=12)
axs[1][0].text(-0.08, 1, f'({chr(97 + 2)})', transform=axs[1][0].transAxes, verticalalignment='top', fontsize=12)
axs[1][1].text(-0.08, 1, f'({chr(97 + 3)})', transform=axs[1][1].transAxes, verticalalignment='top', fontsize=12)

plt.tight_layout()
# fig.suptitle('Training Result for CNN encoders w/wo Robot Kinematics Information')
plt.savefig('together.png', format='png')
